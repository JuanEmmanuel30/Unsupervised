# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanEmmanuel30/Unsupervised/blob/main/TRABALHO_POS_MARCO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

path = kagglehub.dataset_download("rohan0301/unsupervised-learning-on-country-data")

print("Path to dataset files:", path)

import os

# 'path' é a variável que você já tem do kagglehub
print(f"Arquivos encontrados em '{path}':")
print(os.listdir(path))


import pandas as pd
import os

# --- Substitua pelo nome do arquivo que você viu na Etapa 1 ---
nome_do_arquivo = 'Country-data.csv'
# -----------------------------------------------------------

# Cria o caminho completo: "pasta/arquivo.csv"
caminho_completo = os.path.join(path, nome_do_arquivo)

print(f"Carregando o arquivo: {caminho_completo}")

# Carrega o arquivo CSV para um DataFrame
df = pd.read_csv(caminho_completo)

# Mostra as 5 primeiras linhas para confirmar
print(df.count)
total_itens = df['country'].count()
print(f"A coluna tem {total_itens} itens preenchidos.")
# Out:
# ...
# 100%|██████████| 5.21k/5.21k [00:00<00:00, 5.93MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/rohan0301/unsupervised-learning-on-country-data/versions/2
# Arquivos encontrados em '/root/.cache/kagglehub/datasets/rohan0301/unsupervised-learning-on-country-data/versions/2':
# ['data-dictionary.csv', 'Country-data.csv']
# Carregando o arquivo: /root/.cache/kagglehub/datasets/rohan0301/unsupervised-learning-on-country-data/versions/2/Country-data.csv
# <bound method DataFrame.count of                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import kagglehub

# Baixar o dataset do Kaggle
path = kagglehub.dataset_download("rohan0301/unsupervised-learning-on-country-data")

print("Path to dataset files:", path)

# Carregamento do arquivo CSV
arquivo = os.path.join(path, "Country-data.csv")
df = pd.read_csv(arquivo)

# Visualizacao das primeiras linhas
print(df.head())
# Out:
# Using Colab cache for faster access to the 'unsupervised-learning-on-country-data' dataset.
# Path to dataset files: /kaggle/input/unsupervised-learning-on-country-data
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
import pandas as pd
import os
import kagglehub
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Baixar e carregar dataset
path = kagglehub.dataset_download("rohan0301/unsupervised-learning-on-country-data")
arquivo = os.path.join(path, "Country-data.csv")
df = pd.read_csv(arquivo)

# Definição da variável-alvo binária
limiar = df["income"].median()
df["target"] = (df["income"] >= limiar).astype(int)

# Features numéricas
X = df.drop(columns=["country", "income", "target"])
y = df["target"]

# Divisão em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=95)

# Normalização
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Modelo Perceptron
perceptron = Perceptron(max_iter=1000, random_state=95)
perceptron.fit(X_train, y_train)

# Predições
y_pred = perceptron.predict(X_test)

# Métricas
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1-score:", f1_score(y_test, y_pred))
# Out:
# ...
# 100%|██████████| 5.21k/5.21k [00:00<00:00, 7.68MB/s]
# Extracting files...
# Accuracy: 0.8283582089552238
# Precision: 0.9782608695652174
# Recall: 0.6716417910447762
# F1-score: 0.7964601769911505

# %%
import pandas as pd
import os
import kagglehub
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Baixar e carregar dataset
path = kagglehub.dataset_download("rohan0301/unsupervised-learning-on-country-data")
arquivo = os.path.join(path, "Country-data.csv")
df = pd.read_csv(arquivo)

# Definição da variável-alvo binária
limiar = df["income"].median()
df["target"] = (df["income"] >= limiar).astype(int)

# Features numéricas (excluímos 'country', 'income' e 'target')
X = df.drop(columns=["country", "income", "target"])
y = df["target"]

# Divisão em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=95)

# Normalização
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Treinamento da Árvore de Decisão (parâmetros padrão)
tree = DecisionTreeClassifier(random_state=95, max_depth=None)  # sem limite de profundidade
tree.fit(X_train, y_train)

# Predições
y_pred_tree = tree.predict(X_test)

# Métricas
print("Accuracy (Árvore):", accuracy_score(y_test, y_pred_tree))
print("Precision (Árvore):", precision_score(y_test, y_pred_tree))
print("Recall (Árvore):", recall_score(y_test, y_pred_tree))
print("F1-score (Árvore):", f1_score(y_test, y_pred_tree))
# Out:
# ...
# 100%|██████████| 5.21k/5.21k [00:00<00:00, 8.79MB/s]
# Extracting files...
# Accuracy (Árvore): 0.9626865671641791
# Precision (Árvore): 0.9696969696969697
# Recall (Árvore): 0.9552238805970149
# F1-score (Árvore): 0.9624060150375939

# %%
from sklearn.tree import export_text

# Exportar regras da árvore
tree_rules = export_text(tree, feature_names=list(X.columns))
print(tree_rules)
# Out:
# |--- gdpp <= -0.43
# |   |--- life_expec <= 0.41
# |   |   |--- class: 0
# |   |--- life_expec >  0.41
# |   |   |--- inflation <= 0.52
# |   |   |   |--- class: 0
# |   |   |--- inflation >  0.52
# |   |   |   |--- class: 1
# |--- gdpp >  -0.43
# |   |--- class: 1

# %%
import pandas as pd
import os
import kagglehub
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Baixar e carregar dataset
path = kagglehub.dataset_download("rohan0301/unsupervised-learning-on-country-data")
arquivo = os.path.join(path, "Country-data.csv")
df = pd.read_csv(arquivo)

# Definição da variável-alvo binária
limiar = df["income"].median()
df["target"] = (df["income"] >= limiar).astype(int)

# Features numéricas (excluímos 'country', 'income' e 'target')
X = df.drop(columns=["country", "income", "target"])
y = df["target"]

# Divisão em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=95)

# Normalização
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Espaço de busca de hiperparâmetros relevante
param_grid = {
    "max_depth": [None, 4, 6, 10],
    "min_samples_split": [2, 10], # Alterado: removido o valor 1
    "min_samples_leaf": [1, 2, 5],
    "criterion": ["gini", "entropy"]
}

# Modelo base
tree = DecisionTreeClassifier(random_state=95)

# Grid Search com validação cruzada
grid_search = GridSearchCV(tree, param_grid, cv=4, scoring="f1", n_jobs=-1, return_train_score=True)
grid_search.fit(X_train, y_train)

print("Melhores hiperparâmetros:", grid_search.best_params_)
print("Melhor F1-score médio em validação cruzada:", grid_search.best_score_)

# Modelo otimizado
best_tree = grid_search.best_estimator_
y_pred_best = best_tree.predict(X_test)

# Avaliação no conjunto de teste
print("Accuracy (Otimizado):", accuracy_score(y_test, y_pred_best))
print("Precision (Otimizado):", precision_score(y_test, y_pred_best))
print("Recall (Otimizado):", recall_score(y_test, y_pred_best))
print("F1-score (Otimizado):", f1_score(y_test, y_pred_best))
# Out:
# Using Colab cache for faster access to the 'unsupervised-learning-on-country-data' dataset.
# Melhores hiperparâmetros: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Melhor F1-score médio em validação cruzada: 0.861111111111111
# Accuracy (Otimizado): 0.9626865671641791
# Precision (Otimizado): 0.9696969696969697
# Recall (Otimizado): 0.9552238805970149
# F1-score (Otimizado): 0.9624060150375939

# %%
import numpy as np

import pandas as pd



# Extrair coeficientes e bias

coeficientes = perceptron.coef_[0]

bias = perceptron.intercept_[0]



# Criar DataFrame com features e coeficientes

df_coef = pd.DataFrame({

    "Feature": X.columns,

    "Coeficiente": coeficientes,

    "Importância (abs)": np.abs(coeficientes)

})



# Ordenar por importância

df_coef = df_coef.sort_values(by="Importância (abs)", ascending=False)



print("Bias (intercepto):", bias)

print("\nRanking das variáveis por importância:")

print(df_coef)
# Out:
# Bias (intercepto): -1.0
#
# Ranking das variáveis por importância:
#       Feature  Coeficiente  Importância (abs)
# 7        gdpp     6.515300           6.515300
# 5  life_expec     4.132364           4.132364
# 0  child_mort    -3.875233           3.875233
# 6   total_fer     1.705049           1.705049
# 1     exports     1.555590           1.555590
# 4   inflation     0.802722           0.802722
# 2      health    -0.518335           0.518335
# 3     imports    -0.078157           0.078157

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import GridSearchCV



#  hiperparâmetros relevante para Random Forest

param_grid = {

    "n_estimators": [100, 150, 250],      # número de árvores

    "max_depth": [None, 5, 15],          # profundidade máxima

    "min_samples_split": [2, 6, 8],

    "min_samples_leaf": [1, 2, 4],

    "criterion": ["gini", "entropy"]

}



# Modelo base

rf = RandomForestClassifier(random_state=95)



# Grid Search com validação cruzada (5-fold)

grid_search = GridSearchCV(rf, param_grid, cv=4, scoring="f1", n_jobs=-2, return_train_score=True)

grid_search.fit(X_train, y_train)



print("Melhores hiperparâmetros:", grid_search.best_params_)

print("Melhor F1-score médio em validação cruzada:", grid_search.best_score_)





# Avaliação no conjunto de teste

print("Accuracy (RF):", accuracy_score(y_test, y_pred_rf))

print("Precision (RF):", precision_score(y_test, y_pred_rf))

print("Recall (RF):", recall_score(y_test, y_pred_rf))

print("F1-score (RF):", f1_score(y_test, y_pred_rf))



# Importância das features

importances = best_rf.feature_importances_

feature_importance = pd.DataFrame({"Feature": X.columns, "Importância": importances})

print(feature_importance.sort_values(by="Importância", ascending=False))
# Out:
# Melhores hiperparâmetros: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Melhor F1-score médio em validação cruzada: 0.861111111111111
# Accuracy (RF): 0.9104477611940298
# Precision (RF): 1.0
# Recall (RF): 0.8208955223880597
# F1-score (RF): 0.9016393442622951
#       Feature  Importância
# 7        gdpp     0.340130
# 5  life_expec     0.263086
# 0  child_mort     0.158706
# 6   total_fer     0.090271
# 2      health     0.071032
# 1     exports     0.034006
# 4   inflation     0.024216
# 3     imports     0.018554
